# %%
import gc
import os
import re
import string
import time
from collections import defaultdict
from contextlib import contextmanager

import lightgbm as lgb
import nltk
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import psutil
import seaborn as sns
import textblob as tb
import xgboost as xgb
from nltk import wordpunct_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import *
from nltk.stem.wordnet import WordNetLemmatizer
from pandas_profiling import ProfileReport
from scipy.sparse import csr_matrix, hstack
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import (LogisticRegression, RidgeClassifier,
                                  RidgeClassifierCV)
from sklearn.metrics import f1_score, precision_recall_curve, roc_auc_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %matplotlib inline

# %%
print(os.listdir("../input"))
# Out:
# ['train.csv', 'sample_submission.csv', 'test.csv']

# %%
path = "../input/"

# %% [markdown]
# ### Data import

# %%
# Load train and test data
train = pd.read_csv(path + "train.csv", index_col="id")
test = pd.read_csv(path + "test.csv", index_col="id")

# Concatenate train and test in one dataframe
df = pd.concat([train.drop("label", axis=1), test], axis=0)

# Separate labels
label = train.label

submission = pd.read_csv(path + "sample_submission.csv")

# %%
print(
    "Train data shape:{}\nTest data shape:{}\nFull set shape{}".format(
        train.shape, test.shape, df.shape
    )
)
# Out:
# Train data shape:(7920, 2)
# Test data shape:(1953, 1)
# Full set shape(9873, 1)

# %% [markdown]
# ### Exploration

# %%
# Check number of 0/1 labels in the dataset
label.value_counts() / label.shape[0]
# Out:
# 0    0.744192
# 1    0.255808
# Name: label, dtype: float64

# %%
# Take a glimpse at the data
df.head()
# Out:
#                                                 tweet
# id
# 1   #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2   Finally a transparant silicon case ^^ Thanks t...
# 3   We love this! Would you go? #talk #makememorie...
# 4   I'm wired I know I'm George I was made that wa...
# 5   What amazing service! Apple won't even talk to...

# %%
train[train.label == 1].head()
# Out:
#     label                                              tweet
# id
# 5       1  What amazing service! Apple won't even talk to...
# 6       1  iPhone software update fucked up my phone big ...
# 11      1  hey #apple when you make a new ipod dont make ...
# 12      1  Ha! Not heavy machinery but it does what I nee...
# 13      1  Contemplating giving in to the iPhone bandwago...

# %%
train[train.label == 0].head()
# Out:
#     label                                              tweet
# id
# 1       0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2       0  Finally a transparant silicon case ^^ Thanks t...
# 3       0  We love this! Would you go? #talk #makememorie...
# 4       0  I'm wired I know I'm George I was made that wa...
# 7       0  Happy for us .. #instapic #instadaily #us #son...

# %% [markdown]
# ### WordCloud

# %%
neg_tweets = train[train.label == 1]
neg_string = []
for t in neg_tweets.tweet:
    neg_string.append(t)
neg_string = pd.Series(neg_string).str.cat(sep=" ")

wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(neg_string)
plt.figure(figsize=(12, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
neg_tweets = train[train.label == 0]
neg_string = []
for t in neg_tweets.tweet:
    neg_string.append(t)
neg_string = pd.Series(neg_string).str.cat(sep=" ")

wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(neg_string)
plt.figure(figsize=(12, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
def count_regexp_occ(regexp="", text=None):
    """ Simple way to get the number of occurence of a regex"""
    return len(re.findall(regexp, text))

# %%
# Get length in words and characters
df["raw_word_len"] = df["tweet"].apply(lambda x: len(x.split()))
df["raw_char_len"] = df["tweet"].apply(lambda x: len(x))
# Check number of upper case, if you're angry you may write in upper case
df["nb_upper"] = df["tweet"].apply(lambda x: count_regexp_occ(r"[A-Z]", x))
df["caps_vs_len"] = (df["nb_upper"] / df["raw_char_len"]) * 100
# Check for punctuation
df["num_punctuation"] = df["tweet"].apply(
    lambda comment: sum(comment.count(w) for w in ".,;:")
)
df["punc_vs_len"] = (df["num_punctuation"] / df["raw_char_len"]) * 100
# Check for http links
df["has_http"] = df["tweet"].apply(lambda x: count_regexp_occ(r"http[s]{0,1}://\S+", x))
df["has_http"] = df["has_http"] > 0
df["has_http"] = df["has_http"].astype(int)

# %%
df.columns
# Out:
# Index(['tweet', 'raw_word_len', 'raw_char_len', 'nb_upper', 'caps_vs_len',
#        'num_punctuation', 'punc_vs_len', 'has_http'],
#       dtype='object')

# %%
numcols = [
    "raw_word_len",
    "raw_char_len",
    "nb_upper",
    "caps_vs_len",
    "num_punctuation",
    "punc_vs_len",
]

# %%
df[numcols] = np.log1p(df[numcols])

# %% [markdown]
# ## Clean text

# %% [markdown]
# ### Remove twitter handles (@user)

# %%
def remove_pattern(text, pattern):
    r = re.findall(pattern, text)
    for i in r:
        text = re.sub(i, "", text)
    return text

# %%
df["tidy_tweet"] = np.vectorize(remove_pattern)(df["tweet"], r"@[A-Za-z0-9_]+")

# %% [markdown]
# ### Replace english contractions

# %%
cont_patterns = [
    ("(W|w)on't", "will not"),
    ("(C|c)an't", "can not"),
    ("(I|i)'m", "i am"),
    ("(A|a)in't", "is not"),
    ("(\w+)'ll", "\g<1> will"),
    ("(\w+)n't", "\g<1> not"),
    ("(\w+)'ve", "\g<1> have"),
    ("(\w+)'s", "\g<1> is"),
    ("(\w+)'re", "\g<1> are"),
    ("(\w+)'d", "\g<1> would"),
]
patterns = [(re.compile(regex), repl) for (regex, repl) in cont_patterns]

# %%
def clean_text(text):
    clean = text.lower()
    # Drop numbers
    clean = re.sub("\d+", " ", clean)
    # Remove extra spaces
    clean = re.sub("\s+", " ", clean)
    # Remove ending space if any
    clean = re.sub("\s+$", "", clean)
    for (pattern, repl) in patterns:
        clean = re.sub(pattern, repl, clean)
    return clean

# %%
df["tidy_tweet"] = df["tidy_tweet"].apply(lambda x: clean_text(x))

# %%
# remove http links
df["tidy_tweet"] = df["tidy_tweet"].str.replace(r"https?://[^ ]+", "")
df["tidy_tweet"] = df["tidy_tweet"].str.replace(r"www.[^ ]+", "")

# %%
# remove hashtags
# df['tidy_tweet'] = df['tidy_tweet'].str.replace(r"#(\w+)", " ")

# %%
# remove special characters, numbers, punctuations
df["tidy_tweet"] = df["tidy_tweet"].str.replace("[^a-zA-Z#]", " ")

# %%
# Get the new length in words and characters
df["clean_word_len"] = df["tidy_tweet"].apply(lambda x: len(x.split()))
df["clean_char_len"] = df["tidy_tweet"].apply(lambda x: len(x))
# Number of different characters used in a comment
# Using the f word only will reduce the number of letters required in the comment
df["clean_chars"] = df["tidy_tweet"].apply(lambda x: len(set(x)))
df["clean_chars_ratio"] = df["tidy_tweet"].apply(lambda x: len(set(x))) / df[
    "tidy_tweet"
].apply(lambda x: 1 + min(99, len(x)))

# %% [markdown]
# ## TF-IDF

# %%
def char_analyzer(text):
    """
    This is used to split strings in small lots
    so <talk> and <talking> would have <Tal> <alk> in common
    """
    tokens = text.split()
    return [token[i : i + 3] for token in tokens for i in range(len(token) - 2)]

# %%
# Get TF-IDF features
train_text = df.iloc[: train.shape[0], :]["tidy_tweet"]
test_text = df.iloc[train.shape[0] :, :]["tidy_tweet"]
all_text = pd.concat([train_text, test_text])

# %%
# Use the char_analyzer to get another TFIDF
# Char level TFIDF would go through words when char analyzer only considers
# characters inside a word
char_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    strip_accents="unicode",
    tokenizer=char_analyzer,
    analyzer="word",
    ngram_range=(1, 3),
    max_features=50000,
)
char_vectorizer.fit(all_text)
train_char_features = char_vectorizer.transform(train_text)
test_char_features = char_vectorizer.transform(test_text)

# %%
tokenized_tweet = all_text.apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# id
# 1    [#fingerprint, #pregnancy, test, mfqv, #androi...
# 2    [finally, a, transparant, silicon, case, thank...
# 3    [we, love, this, would, you, go, #talk, #makem...
# 4    [i, am, wired, i, know, i, am, george, i, was,...
# 5    [what, amazing, service, apple, will, not, eve...
# Name: tidy_tweet, dtype: object

# %%
stemmer = PorterStemmer()
tokenized_tweet = tokenized_tweet.apply(
    lambda x: [stemmer.stem(i) for i in x]
)  # stemming
tokenized_tweet.head()
# Out:
# id
# 1    [#fingerprint, #pregnanc, test, mfqv, #android...
# 2    [final, a, transpar, silicon, case, thank, to,...
# 3    [we, love, thi, would, you, go, #talk, #makeme...
# 4    [i, am, wire, i, know, i, am, georg, i, wa, ma...
# 5    [what, amaz, servic, appl, will, not, even, ta...
# Name: tidy_tweet, dtype: object

# %%
for i in range(1, len(tokenized_tweet)):
    tokenized_tweet[i] = " ".join(tokenized_tweet[i])

# %%
tokenized_tweet.head()
# Out:
# id
# 1    #fingerprint #pregnanc test mfqv #android #app...
# 2    final a transpar silicon case thank to my uncl...
# 3    we love thi would you go #talk #makememori #un...
# 4    i am wire i know i am georg i wa made that way...
# 5    what amaz servic appl will not even talk to me...
# Name: tidy_tweet, dtype: object

# %%
all_text = tokenized_tweet.apply(lambda x: str(x))
train_text = all_text[: train.shape[0]]
test_text = all_text[train.shape[0] :]
all_text.head()
# Out:
# id
# 1    #fingerprint #pregnanc test mfqv #android #app...
# 2    final a transpar silicon case thank to my uncl...
# 3    we love thi would you go #talk #makememori #un...
# 4    i am wire i know i am georg i wa made that way...
# 5    what amaz servic appl will not even talk to me...
# Name: tidy_tweet, dtype: object

# %%
# First on real words
word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    strip_accents="unicode",
    analyzer="word",
    token_pattern=r"\w{1,}",
    stop_words="english",
    ngram_range=(1, 2),
    max_features=20000,
)

word_vectorizer.fit(all_text)
train_word_features = word_vectorizer.transform(train_text)
test_word_features = word_vectorizer.transform(test_text)

# %%
all_text = all_text.apply(lambda x: str(x))

# %% [markdown]
# ## Prepare numerical features

# %%
# Scaling numerical features with MinMaxScaler though tree boosters don't need that
num_features = [f_ for f_ in df.columns if f_ not in ["tweet", "tidy_tweet"]]

skl = MinMaxScaler()
train_num_features = csr_matrix(
    skl.fit_transform(df.iloc[: train.shape[0], :][num_features])
)
test_num_features = csr_matrix(
    skl.fit_transform(df.iloc[train.shape[0] :, :][num_features])
)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# ## Stack TF-IDF Matrixes

# %%
csr_trn = hstack([train_char_features, train_word_features, train_num_features]).tocsr()

# %%
csr_sub = hstack([test_char_features, test_word_features, test_num_features]).tocsr()

# %% [markdown]
# ## Logistic Regression

# %%
scores = []
folds = KFold(n_splits=8, shuffle=True, random_state=42)
train_pred = np.zeros(train.shape[0])
prediction = np.zeros(test.shape[0])
train_target = train.label

# %%
# Set regression parameters
all_parameters = {
    "C": 1,
    "tol": 0.1,
    "solver": "lbfgs",
    "fit_intercept": True,
    "penalty": "l2",
    "class_weight": "balanced",
    "verbose": 0,
}

# %%
classifier = LogisticRegression(**all_parameters)

# %%
trn_idx = list(enumerate(folds.split(train, train_target)))[0][1][0]

# %%
train_pred = np.zeros(train.shape[0])
prediction = np.zeros(test.shape[0])
train_target = train.label
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(train, train_target)):
    # Train LR
    classifier.fit(csr_trn[trn_idx], train_target.values[trn_idx])
    train_pred[val_idx] = classifier.predict_proba(csr_trn[val_idx])[:, 1]
    prediction += classifier.predict_proba(csr_sub)[:, 1] / folds.n_splits
    rscore = roc_auc_score(train_target.values[val_idx], train_pred[val_idx])

    print("\t Fold %d : %.6f ROC AUC" % (n_fold + 1, rscore))
# Out:
# 	 Fold 1 : 0.961544 ROC AUC
# 	 Fold 2 : 0.949475 ROC AUC
# 	 Fold 3 : 0.954640 ROC AUC
# 	 Fold 4 : 0.941978 ROC AUC
# 	 Fold 5 : 0.960051 ROC AUC
# 	 Fold 6 : 0.955209 ROC AUC
# 	 Fold 7 : 0.955206 ROC AUC
# 	 Fold 8 : 0.956434 ROC AUC

# %%
print("full score : %.6f" % roc_auc_score(train_target, train_pred))
# Out:
# full score : 0.954301

# %%
train_pred_lr = train_pred.copy()

# %%
precision, recall, tresh = precision_recall_curve(train_target, train_pred)
f1 = []
for t in range(len(tresh)):
    f1.append(2 / ((1 / precision[t]) + (1 / recall[t])))
th = tresh[np.argmax(f1)]

# %%
train_prediction = train_pred >= th
train_prediction = train_prediction.astype(int)

# %%
print("full score : %.6f" % f1_score(train_target, train_prediction))
# Out:
# full score : 0.822396

# %%
prediction_lr = prediction.copy()

# %%
prediction = prediction - min(prediction)
prediction = prediction / max(prediction)
prediction = prediction >= th
prediction = prediction.astype(int)

# %%
submission["label"] = prediction

# %%
submission.to_csv("lr_submission.csv", index=False)

# %% [markdown]
# ## LightGBM

# %%
folds = KFold(n_splits=8, shuffle=True, random_state=42)

# %%
# Set LGBM parameters
params = {
    "objective": "binary",
    "metric": {"auc"},
    "boosting_type": "gbdt",
    "verbosity": -1,
    "num_threads": 4,
    "bagging_fraction": 0.8,
    "feature_fraction": 0.8,
    "learning_rate": 0.05,
    "num_leaves": 64,
    "verbose": -1,
    "min_split_gain": 0.1,
    "reg_alpha": 0.1,
}

# %%
lgb_round_dict = defaultdict(int)
trn_lgbset = lgb.Dataset(csr_trn, free_raw_data=False)

# %%
train_pred = np.zeros(train.shape[0])
prediction = np.zeros(test.shape[0])
trn_lgbset.set_label(train_target.values)
lgb_rounds = 5000
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(train, train_target)):
    watchlist = [trn_lgbset.subset(trn_idx), trn_lgbset.subset(val_idx)]
    # Train lgb l1
    model = lgb.train(
        params=params,
        train_set=watchlist[0],
        num_boost_round=lgb_rounds,
        valid_sets=watchlist,
        early_stopping_rounds=50,
        verbose_eval=0,
    )
    train_pred[val_idx] = model.predict(
        trn_lgbset.data[val_idx], num_iteration=model.best_iteration
    )
    prediction += (
        model.predict(csr_sub, num_iteration=model.best_iteration) / folds.n_splits
    )
    rscore = roc_auc_score(train_target.values[val_idx], train_pred[val_idx])

    print(
        "\t Fold %d : %.6f ROC AUC in %3d rounds"
        % (n_fold + 1, rscore, model.best_iteration)
    )
# Out:
# 	 Fold 1 : 0.964916 ROC AUC in 151 rounds
# 	 Fold 2 : 0.950810 ROC AUC in 148 rounds
# 	 Fold 3 : 0.955962 ROC AUC in 150 rounds
# 	 Fold 4 : 0.944681 ROC AUC in 102 rounds
# 	 Fold 5 : 0.956528 ROC AUC in 148 rounds
# 	 Fold 6 : 0.954237 ROC AUC in 128 rounds
# 	 Fold 7 : 0.957234 ROC AUC in 156 rounds
# 	 Fold 8 : 0.954580 ROC AUC in 121 rounds

# %%
train_pred_lgb = train_pred.copy()

# %%
print("full score : %.6f" % roc_auc_score(train_target, train_pred))
# Out:
# full score : 0.954824

# %%
precision, recall, tresh = precision_recall_curve(train_target, train_pred)
f1 = []
for t in range(len(tresh)):
    f1.append(2 / ((1 / precision[t]) + (1 / recall[t])))
th = tresh[np.argmax(f1)]

# %%
train_prediction = train_pred >= th
train_prediction = train_prediction.astype(int)

# %%
print("full score : %.6f" % f1_score(train_target, train_prediction))
# Out:
# full score : 0.820755

# %%
prediction_lgb = prediction.copy()

# %%
prediction = prediction - min(prediction)
prediction = prediction / max(prediction)
prediction = prediction >= th
prediction = prediction.astype(int)

# %%
submission["label"] = prediction

# %%
submission.to_csv("lgbm_stem_submission.csv", index=False)

# %% [markdown]
# ## XGBoost

# %%
folds = KFold(n_splits=8, shuffle=True, random_state=42)

# %%
# Set XGBoost parameters
param = {}
param["objective"] = "binary:logistic"
param["eta"] = 0.1
param["max_depth"] = 6
param["silent"] = 1
param["eval_metric"] = "auc"
param["min_child_weight"] = 1
param["subsample"] = 0.7
param["colsample_bytree"] = 0.7
param["seed"] = 23

plst = list(param.items())

# %%
xgtrain = xgb.DMatrix(csr_trn, label=train.label.values)
xgtest = xgb.DMatrix(csr_sub)

# %%
train_pred = np.zeros(train.shape[0])
prediction = np.zeros(test.shape[0])
num_rounds = 500
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(train, train_target)):
    watchlist = [(xgtrain.slice(trn_idx), "train"), (xgtrain.slice(val_idx), "test")]
    # Train xgb
    model = xgb.train(
        params=plst,
        dtrain=xgtrain.slice(trn_idx),
        num_boost_round=500,
        evals=watchlist,
        early_stopping_rounds=20,
        verbose_eval=50,
    )

    train_pred[val_idx] = model.predict(
        xgtrain.slice(val_idx), ntree_limit=model.best_ntree_limit
    )
    prediction += (
        model.predict(xgtest, ntree_limit=model.best_ntree_limit) / folds.n_splits
    )
    rscore = roc_auc_score(train_target.values[val_idx], train_pred[val_idx])

    print(
        "\t Fold %d : %.6f ROC AUC in %3d rounds"
        % (n_fold + 1, rscore, model.best_iteration)
    )
# Out:
# [0]	train-auc:0.924985	test-auc:0.930432
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.982307	test-auc:0.960969
# Stopping. Best iteration:
# [64]	train-auc:0.985904	test-auc:0.962287
#
# 	 Fold 1 : 0.962287 ROC AUC in  64 rounds
# [0]	train-auc:0.929808	test-auc:0.90277
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.983511	test-auc:0.943753
# [100]	train-auc:0.992212	test-auc:0.944817
# Stopping. Best iteration:
# [81]	train-auc:0.989546	test-auc:0.945525
#
# 	 Fold 2 : 0.945525 ROC AUC in  81 rounds
# [0]	train-auc:0.921555	test-auc:0.908799
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.983625	test-auc:0.949223
# [100]	train-auc:0.991704	test-auc:0.950075
# [150]	train-auc:0.996185	test-auc:0.952159
# [200]	train-auc:0.998006	test-auc:0.952804
# Stopping. Best iteration:
# [189]	train-auc:0.997624	test-auc:0.952902
#
# 	 Fold 3 : 0.952902 ROC AUC in 189 rounds
# [0]	train-auc:0.926726	test-auc:0.904348
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.983905	test-auc:0.939073
# [100]	train-auc:0.991888	test-auc:0.943437
# Stopping. Best iteration:
# [89]	train-auc:0.990423	test-auc:0.944127
#
# 	 Fold 4 : 0.944127 ROC AUC in  89 rounds
# [0]	train-auc:0.93168	test-auc:0.916923
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.982729	test-auc:0.950554
# [100]	train-auc:0.991059	test-auc:0.951704
# Stopping. Best iteration:
# [80]	train-auc:0.98842	test-auc:0.952318
#
# 	 Fold 5 : 0.952318 ROC AUC in  80 rounds
# [0]	train-auc:0.923654	test-auc:0.920041
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.983644	test-auc:0.950908
# [100]	train-auc:0.991993	test-auc:0.952575
# Stopping. Best iteration:
# [127]	train-auc:0.994174	test-auc:0.953358
#
# 	 Fold 6 : 0.953358 ROC AUC in 127 rounds
# [0]	train-auc:0.927918	test-auc:0.911609
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.984104	test-auc:0.951406
# [100]	train-auc:0.992674	test-auc:0.954554
# [150]	train-auc:0.996203	test-auc:0.955805
# Stopping. Best iteration:
# [149]	train-auc:0.996124	test-auc:0.95623
#
# 	 Fold 7 : 0.956230 ROC AUC in 149 rounds
# [0]	train-auc:0.930096	test-auc:0.913488
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [50]	train-auc:0.983543	test-auc:0.950833
# [100]	train-auc:0.992477	test-auc:0.952973
# Stopping. Best iteration:
# [118]	train-auc:0.994041	test-auc:0.954186
#
# 	 Fold 8 : 0.954186 ROC AUC in 118 rounds

# %%
train_pred_xgb = train_pred.copy()

# %%
print("full score : %.6f" % roc_auc_score(train_target, train_pred))
# Out:
# full score : 0.952235

# %%
precision, recall, tresh = precision_recall_curve(train_target, train_pred)
f1 = []
for t in range(len(tresh)):
    f1.append(2 / ((1 / precision[t]) + (1 / recall[t])))
th = tresh[np.argmax(f1)]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   after removing the cwd from sys.path.

# %%
train_prediction = train_pred >= th
train_prediction = train_prediction.astype(int)

# %%
print("full score : %.6f" % f1_score(train_target, train_prediction))
# Out:
# full score : 0.815795

# %%
prediction_xgb = prediction.copy()

# %%
prediction = prediction - min(prediction)
prediction = prediction / max(prediction)
prediction = prediction >= th
prediction = prediction.astype(int)

# %%
submission["label"] = prediction

# %%
submission.to_csv("xgb_submission.csv", index=False)

# %% [markdown]
# ## Ensemble

# %%
train_pred = np.power((train_pred_lr * train_pred_xgb * train_pred_lgb), 1 / 3)

# %%
precision, recall, tresh = precision_recall_curve(train_target, train_pred)
f1 = []
for t in range(len(tresh)):
    f1.append(2 / ((1 / precision[t]) + (1 / recall[t])))
th = tresh[np.argmax(f1)]

# %%
train_prediction = train_pred >= th
train_prediction = train_prediction.astype(int)

# %%
print("full score : %.6f" % f1_score(train_target, train_prediction))
# Out:
# full score : 0.824752

# %%
prediction = np.power((prediction_lgb * prediction_xgb * prediction_lr), 1 / 3)

# %%
prediction = prediction - min(prediction)
prediction = prediction / max(prediction)
prediction = prediction >= th
prediction = prediction.astype(int)

# %%
submission["label"] = prediction

# %%
submission.to_csv("ensemble_submission.csv", index=False)
